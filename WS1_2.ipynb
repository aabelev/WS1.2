# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.optimize import curve_fit

#time in seconds
time = np.array([0., 10., 20., 30., 39., 49., 58.,  67.,  78.,  88., 99.,
       109., 119., 129., 140., 154., 170., 180., 190., 200.])

#concentrations in g/L
concentration = np.array([0, 0.02, 0.15, 0.4, 0.62, 0.71, 0.48, 0.36, 0.25,
        0.19, 0.15, 0.12, 0.1, 0.08, 0.06, 0.04, 0.02, 0.01, 0, 0])

#plot
plt.plot(time, concentration, marker='o')
plt.ylabel("Concentration [g/L]")
plt.xlabel("Time [s]")
plt.title("Concentration of Salt in the River")
plt.show()
# Out:
# Matplotlib is building the font cache; this may take a moment.

# %%
# Compute the area under the concentration curve by numerical 
# integration. Compare two numerical integration methods of your 
# choice. Use the time and concentration arrays from the cell above.
